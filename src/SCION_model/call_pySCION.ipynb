# %%
import time
import SCION_initialise
import SCION_classes
import numpy as np

import scipy.io as sp

# %%
res, INTERPSTACK = SCION_initialise.SCION_initialise(-1)
# Out:
# setting parameters... 3.814697265625e-06
# Arcs are turned ON!
# Sutures are turned ON!
# Degassing is turned ON!
# Bio is turned ON!
# PALAEOGEOG is turned ON!
# Done
# time: 2.7894973754882812e-05
# loading forcings... 3.1948089599609375e-05
# Done
# time: 0.15937185287475586
# Beginning run:
# /Users/andrew/Documents/GitHub/pySCION/SCION_equations.py:340: RuntimeWarning: invalid value encountered in multiply
#   CW_per_km2_past_raw = 1e6 * EPSILON_past * Xm * (1 - np.exp(-1 * K * R_Q_past * R_T_past * R_reg_past))
# /Users/andrew/Documents/GitHub/pySCION/SCION_equations.py:341: RuntimeWarning: invalid value encountered in multiply
#   CW_per_km2_future_raw = 1e6 * EPSILON_future * Xm * (1 - np.exp(-1 * K * R_Q_future * R_T_future * R_reg_future))
# /Users/andrew/Documents/GitHub/pySCION/SCION_classes.py:115: RuntimeWarning: invalid value encountered in multiply
#   CW_per_km2_present_raw = 1e6 * EPSILON_present * Xm * (1 - np.exp(-1 * K * R_Q_present * R_T_present * R_reg_past))
# Model step: 200 	 time: -599.6897393331814 	 next keyframe: -540
#
# Model step: 400 	 time: -575.7807015803593 	 next keyframe: -540
#
# Model step: 600 	 time: -558.5582339010815 	 next keyframe: -540
#
# Model step: 800 	 time: -540.1121529704644 	 next keyframe: -540
#
# Model step: 1000 	 time: -524.6490974714948 	 next keyframe: -500
#
# Model step: 1200 	 time: -494.2604561324263 	 next keyframe: -470
#
# Model step: 1400 	 time: -457.14886452924117 	 next keyframe: -450
#
# Model step: 1600 	 time: -453.6970024333041 	 next keyframe: -450
#
# Model step: 1800 	 time: -446.3110855606119 	 next keyframe: -430
#
# Model step: 2000 	 time: -443.91194695441067 	 next keyframe: -430
#
# Model step: 2200 	 time: -439.6698091592011 	 next keyframe: -430
#
# Model step: 2400 	 time: -410.74996203810224 	 next keyframe: -400
#
# Model step: 2600 	 time: -393.7978055172248 	 next keyframe: -370
#
# Model step: 2800 	 time: -384.9058549999358 	 next keyframe: -370
#
# Model step: 3000 	 time: -361.83247553539644 	 next keyframe: -340
#
# Model step: 3200 	 time: -307.757930160576 	 next keyframe: -300
#
# Model step: 3400 	 time: -293.0439197017933 	 next keyframe: -280
#
# Model step: 3600 	 time: -279.8587505275669 	 next keyframe: -260
#
# Model step: 3800 	 time: -266.0477378486239 	 next keyframe: -260
#
# Model step: 4000 	 time: -227.06592990623597 	 next keyframe: -220
#
# Model step: 4200 	 time: -206.74786002191397 	 next keyframe: -200
#
# Model step: 4400 	 time: -163.65642787002793 	 next keyframe: -145
#
# Model step: 4600 	 time: -139.98564180141986 	 next keyframe: -90
#
# Model step: 4800 	 time: -119.28250760750025 	 next keyframe: -90
#
# Model step: 5000 	 time: -113.45136955609266 	 next keyframe: -90
#
# Model step: 5200 	 time: -79.22145065703987 	 next keyframe: -70
#
# Model step: 5400 	 time: -68.70345389292454 	 next keyframe: -52
#
# Model step: 5600 	 time: -58.998000534857105 	 next keyframe: -52
#
# Model step: 5800 	 time: -46.76321784442379 	 next keyframe: -30
#
# Model step: 6000 	 time: -14.567541475830136 	 next keyframe: -15
#
# Model step: 6200 	 time: 0.0 	 next keyframe: 0
#
# Integration finished
# Total steps: 6202
# Output steps: 989
#
# assembling   vectors...
# Done
# time: 4.290860891342163
