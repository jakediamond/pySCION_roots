# %%
import time
import SCION_initialise
import SCION_classes
import numpy as np

import scipy.io as sp

# %%
res, INTERPSTACK = SCION_initialise.SCION_initialise(-1)
# Out:
# setting parameters... 3.814697265625e-06
# Arcs are turned ON!
# Sutures are turned ON!
# Degassing is turned ON!
# Bio is turned ON!
# PALAEOGEOG is turned ON!
# Done
# time: 0.000186920166015625
# loading forcings... 0.0001919269561767578
# Done
# time: 0.1715378761291504
# Beginning run:
# /Users/andrew/Documents/GitHub/pySCION_roots/src/SCION_model/SCION_equations.py:351: RuntimeWarning: invalid value encountered in multiply
#   CW_per_km2_past_raw = 1e6 * EPSILON_past * Xm * (1 - np.exp(-1 * K * R_Q_past * R_T_past * R_reg_past))
# /Users/andrew/Documents/GitHub/pySCION_roots/src/SCION_model/SCION_equations.py:352: RuntimeWarning: invalid value encountered in multiply
#   CW_per_km2_future_raw = 1e6 * EPSILON_future * Xm * (1 - np.exp(-1 * K * R_Q_future * R_T_future * R_reg_future))
# /Users/andrew/Documents/GitHub/pySCION_roots/src/SCION_model/SCION_classes.py:120: RuntimeWarning: invalid value encountered in multiply
#   CW_per_km2_present_raw = 1e6 * EPSILON_present * Xm * (1 - np.exp(-1 * K * R_Q_present * R_T_present * R_reg_past))
# Model step: 200 	 time: -599.6557906118376 	 next keyframe: -540
#
# Model step: 400 	 time: -586.549308133003 	 next keyframe: -540
#
# Model step: 600 	 time: -572.489829929285 	 next keyframe: -540
#
# Model step: 800 	 time: -522.0672684998092 	 next keyframe: -500
#
# Model step: 1000 	 time: -513.0765861820895 	 next keyframe: -500
#
# Model step: 1200 	 time: -497.5485102202167 	 next keyframe: -470
#
# Model step: 1400 	 time: -487.9229121785795 	 next keyframe: -470
#
# Model step: 1600 	 time: -477.2320156224087 	 next keyframe: -470
#
# Model step: 1800 	 time: -454.87855708178654 	 next keyframe: -450
#
# Model step: 2000 	 time: -449.8598875767604 	 next keyframe: -450
#
# Model step: 2200 	 time: -444.39551246917244 	 next keyframe: -430
#
# Model step: 2400 	 time: -436.67401260856974 	 next keyframe: -430
#
# Model step: 2600 	 time: -433.56739489413945 	 next keyframe: -430
#
# Model step: 2800 	 time: -429.7741708009966 	 next keyframe: -400
#
# Model step: 3000 	 time: -410.8721920544953 	 next keyframe: -400
#
# Model step: 3200 	 time: -364.5652597428337 	 next keyframe: -340
#
# Model step: 3400 	 time: -339.3927428967861 	 next keyframe: -300
#
# Model step: 3600 	 time: -310.7941347912339 	 next keyframe: -300
#
# Model step: 3800 	 time: -286.33095771170485 	 next keyframe: -280
#
# Model step: 4000 	 time: -268.53532821146825 	 next keyframe: -260
#
# Model step: 4200 	 time: -259.22915706541073 	 next keyframe: -245
#
# Model step: 4400 	 time: -233.5477286331266 	 next keyframe: -220
#
# Model step: 4600 	 time: -173.5477286331266 	 next keyframe: -145
#
# Model step: 4800 	 time: -100.54772863312661 	 next keyframe: -90
#
# Model step: 5000 	 time: -68.83732423490396 	 next keyframe: -52
#
# Model step: 5200 	 time: -57.70359534668845 	 next keyframe: -52
#
# Model step: 5400 	 time: -10.580568326191909 	 next keyframe: 0
#
# Model step: 5600 	 time: -4.275743374995843 	 next keyframe: 0
#
# Integration finished
# Total steps: 5716
# Output steps: 1014
#
# assembling   vectors...
# Done
# time: 4.376920938491821

# %%
max_root_enhancement_factor = 1.3
root_depths = np.asarray([0, 0, 10, 200, 460])*1.3/460
root_depths
# Out:
# array([0.        , 0.        , 0.02826087, 0.56521739, 1.3       ])

# %%
import matplotlib.pyplot as plt
for i in np.arange(0,21,1):
    plt.figure()
    plt.imshow(INTERPSTACK.root_enhancement[:,:,i])
    plt.title(INTERPSTACK.time[i])
    plt.colorbar()
# Out:
# /var/folders/gs/2q8t31qn5wjb02_tw8sm_c7h0000gn/T/ipykernel_86511/4218411637.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
res.
# Out:
#   Input In [5]
#     res.
#         ^
# SyntaxError: invalid syntax

# %%
plt.scatter(rd_ds.values.flatten(),
            wtd_ds.values.flatten())

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

wtd = xr.load_dataset('/Users/andrew/Downloads/EURASIA_WTD_monthlymeans.nc')
wtd_at_time = wtd.WTD[0,:,:]
coarse = 24
wtd_ds = wtd_at_time.coarsen(lon=coarse).mean().coarsen(lat=coarse).mean()
plt.imshow(wtd_ds, origin='lower',vmin=-100, vmax=0)
plt.colorbar()

# %%
#rd = xr.load_dataset('/Users/andrew/Downloads/maxroot_Europe_and_Asia_CF.nc')
rd_at_time = rd.root_depth
coarse = 24
rd_ds = rd_at_time.coarsen(lon=coarse).mean().coarsen(lat=coarse).mean()
plt.imshow(rd_ds, origin='lower',vmin=0, vmax=20)
plt.colorbar()

# %%
len(rd_ds.values.flatten())

# %%
len(wtd_ds.values.flatten())

# %%
#plt.scatter(np.log(rd_ds.values.flatten()),
#            np.log(np.abs(wtd_ds.values.flatten())))
plt.scatter(np.log(np.abs(wtd_ds.values.flatten())),
            np.log(rd_ds.values.flatten()))

plt.ylabel('root depth')
plt.xlabel('water depth')

# %%
import matplotlib.pyplot as plt
plt.imshow(INTERPSTACK.runoff[:,:,7,-1])
