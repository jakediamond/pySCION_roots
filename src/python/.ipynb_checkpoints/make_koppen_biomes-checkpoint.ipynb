# %%
import scipy.io as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import cartopy.crs as ccrs

# %%
### load INTERPSTACK
file_to_open_INTERPSTACK ='../../data/01_spatial/INTERPSTACK_sep2021_v5.mat'
file_to_open_FLORA ='../../data/01_spatial/FLORA_biome.mat'
mat_contents_INTERP = sp.loadmat(file_to_open_INTERPSTACK)
mat_contents_FLORA = sp.loadmat(file_to_open_FLORA)

CO2 = mat_contents_INTERP['INTERPSTACK'][0][0][0][0]
interp_time = mat_contents_INTERP['INTERPSTACK'][0][0][1][0]
Tair = mat_contents_INTERP['INTERPSTACK'][0][0][2]
runoff = mat_contents_INTERP['INTERPSTACK'][0][0][3]
land = mat_contents_INTERP['INTERPSTACK'][0][0][4]
lat = mat_contents_INTERP['INTERPSTACK'][0][0][5]
biome = mat_contents_FLORA['biome']

# %%
biome_CO2 = [21, 19, 19, 18,	17,	16,	15,	12,	11,	12,	12,	14,	16,	16,	16,	13,	14,	11,	12,	11,	9,	8]

# %%
CO2[8]
# Out:
# 360

# %%
CO2
# Out:
# array([    10,     50,    100,    160,    180,    200,    240,    280,
#           360,    420,    560,    700,    840,   1120,   1400,   1680,
#          2240,   2800,   3360,   4200,   5600,   7000,  14000,  28000,
#         56000, 112000])

# %%
time_CO2
# Out:
# 50

# %%
ice_limit_temp = 5
arid_limit_temp = 20
arid_limit_runoff = 3
biome_land_sea = np.copy(land)
labels = ['sea', 'temperate', 'aboreal', 'tropical', 'leftover', 'ice', 'tundra', 'desert']
for timestep, time_CO2 in enumerate(biome_CO2):
    biome_land_sea[:,:,timestep] = land[:,:,timestep]*biome[:,:,timestep]
    biome_land_sea[:,:,timestep][(Tair[:,:,time_CO2,timestep] < ice_limit_temp) & (biome_land_sea[:,:,timestep] == 4)] = 5
    biome_land_sea[:,:,timestep][(Tair[:,:,time_CO2,timestep] <= arid_limit_temp) & (runoff[:,:,time_CO2, timestep] <= arid_limit_runoff) & (biome_land_sea[:,:,timestep] == 4)] = 6 #tundra
    biome_land_sea[:,:,timestep][(Tair[:,:,time_CO2,timestep] <= arid_limit_temp) & (runoff[:,:,time_CO2, timestep] > arid_limit_runoff) & (biome_land_sea[:,:,timestep] == 4)] = 6 #tundra
    biome_land_sea[:,:,timestep][(Tair[:,:,time_CO2,timestep] > arid_limit_temp) & (runoff[:,:,time_CO2, timestep] < arid_limit_runoff) & (biome_land_sea[:,:,timestep] == 4)] = 7 #desert
    biome_land_sea[:,:,timestep][(Tair[:,:,time_CO2,timestep] > arid_limit_temp) & (runoff[:,:,time_CO2, timestep] > arid_limit_runoff) & (biome_land_sea[:,:,timestep] == 4)] = 3 #tropical?

# %%
fig, ax = plt.subplots(figsize=(12,6))
cax = ax.imshow(biome_land_sea[:,:,timestep])
cbar = fig.colorbar(cax, ticks=[0, 1,2,3,4,5,6,7], orientation='horizontal')
cbar.ax.set_xticklabels(['sea', 'temperate', 'aboreal', 'tropical', 'leftover', 'ice', 'tundra', 'desert'])  # horizontal colorbar
# Out:
# [Text(0, 0, 'sea'),
#  Text(1, 0, 'temperate'),
#  Text(2, 0, 'aboreal'),
#  Text(3, 0, 'tropical'),
#  Text(4, 0, 'leftover'),
#  Text(5, 0, 'ice'),
#  Text(6, 0, 'tundra'),
#  Text(7, 0, 'desert')]

# %%
plt.imshow(biome_land_sea[:,:,0])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(24,6))
biome_at_time = np.roll(biome[:,:,timestep], 24)
#land_at_time = land[:,:,timestep]
land_at_time = land[:,:,timestep]
biome_land_mask = land_at_time*biome_at_time

ax1.imshow(land_at_time)
ax2.imshow(biome_at_time)
sc3 = ax3.imshow(land_at_time*biome_at_time)

fig.colorbar(sc3)

# %%
ice_limit_temp = 5
biome_land_mask[(tair_at_time < ice_limit_temp) & (biome_land_mask == 4)] = 5
plt.imshow(biome_land_mask)
plt.colorbar()

# %%
plt.figure(figsize=(12,6))
arid_limit_temp = 20
arid_limit_runoff = 3
runoff_at_time = runoff[:,:,timestep,co2_step]
biome_land_mask[(tair_at_time <= arid_limit_temp) & (runoff_at_time <= arid_limit_runoff) & (biome_land_mask == 4)] = 6 #tundra
biome_land_mask[(tair_at_time <= arid_limit_temp) & (runoff_at_time > arid_limit_runoff) & (biome_land_mask == 4)] = 6 #tundra
biome_land_mask[(tair_at_time > arid_limit_temp) & (runoff_at_time < arid_limit_runoff) & (biome_land_mask == 4)] = 7 #desert
biome_land_mask[(tair_at_time > arid_limit_temp) & (runoff_at_time > arid_limit_runoff) & (biome_land_mask == 4)] = 3 #tropical?
plt.imshow(biome_land_mask)#, vmin=3, vmax=5)
plt.colorbar()

# %%
plt.imshow(land_at_time[biome_at_time = 4])
plt.colorbar()
# Out:
#   Input In [272]
#     plt.imshow(land_at_time[biome_at_time = 4])
#                                           ^
# SyntaxError: invalid syntax

# %%
plt.imshow(tair_at_time, vmax=20)
plt.colorbar()
